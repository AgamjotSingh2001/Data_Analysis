# %%
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind
from scipy.stats import probplot
import matplotlib.pyplot as plt
import pylab
import seaborn as sns

# %%
shoes=pd.read_csv("women_shoe_prices.csv")
print(shoes.shape)
# Out:
# (33801, 52)
# /tmp/ipykernel_88342/3610950580.py:1: DtypeWarning: Columns (13,16,18,22,24,32,33,40,41,47,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   shoes=pd.read_csv("women_shoe_prices.csv")

# %%
shoes.sample(5)
# Out:
#                          id asins                  brand  \
# 12118  AVpfRtZz1cnluZ0-hpUB   NaN               SoftWalk
# 31715  AVsUuu2PQMlgsOJE7G-P   NaN  Flexus by Spring Step
# 10643  AVpfoio7ilAPnD_xfaLy   NaN            ELLIE SHOES
# 13903  AVpfWS0RilAPnD_xaIw3   NaN            Dance Class
# 3052   AVpf2ccC1cnluZ0-sb88   NaN               Charades
#
#                                               categories         colors  \
# 12118  Shoes,Slip-ons,Women's Shoes,Clogs,Clothing,Al...  Navy Veg Calf
# 31715                        Sandals,Shoes,Women's Shoes            NaN
# 10643     Clothing,Shoes,Women's Shoes,All Women's Shoes            NaN
# 13903  Women's Athletic Shoes,Shoes,Women's Shoes,Clo...            NaN
# 3052      Shoes,Women's Shoes,Clothing,All Women's Shoes  Multi-Colored
#
#        count             dateAdded           dateUpdated  \
# 12118    NaN  2015-08-14T18:08:07Z  2017-03-28T11:42:26Z
# 31715    NaN  2017-03-28T11:44:06Z  2017-03-28T11:44:06Z
# 10643    NaN  2016-02-24T21:01:35Z  2016-02-24T21:01:35Z
# 13903    NaN  2016-11-11T09:49:03Z  2016-11-11T09:49:03Z
# 3052     NaN  2016-11-02T20:08:36Z  2016-11-02T20:08:36Z
#
#                                             descriptions dimension  ...  \
# 12118  [{"dateSeen":["2017-03-25T11:56:28.152Z"],"sou...       NaN  ...
# 31715  [{"dateSeen":["2017-03-25T13:51:13.651Z"],"sou...       NaN  ...
# 10643                                                NaN       NaN  ...
# 13903  [{"dateSeen":["2016-11-11T09:49:03Z"],"sourceU...       NaN  ...
# 3052   [{"dateSeen":["2016-11-02T20:08:35Z"],"sourceU...       NaN  ...
#
#                                                     skus  \
# 12118  [{"sourceURLs":["https://www.overstock.com/Clo...
# 31715  [{"sourceURLs":["https://www.overstock.com/Clo...
# 10643                                                NaN
# 13903                                                NaN
# 3052   [{"sourceURLs":["https://www.walmart.com/ip/Ch...
#
#                                               sourceURLs           upc vin  \
# 12118  https://www.overstock.com/Clothing-Shoes/Women...  8.872470e+11 NaN
# 31715  https://www.overstock.com/Clothing-Shoes/Women...           NaN NaN
# 10643  http://www.walmart.com/ip/Elllie-Thigh-High-Bo...           NaN NaN
# 13903  https://www.walmart.com/ip/Black-Leather-Mesh-...  7.909272e+10 NaN
# 3052   https://www.walmart.com/ip/Charades-Costumes-1...  7.261240e+11 NaN
#
#        websiteIDs   weight Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51
# 12118         NaN      NaN         NaN         NaN         NaN         NaN
# 31715         NaN      NaN         NaN         NaN         NaN         NaN
# 10643         NaN  1.0 lbs         NaN         NaN         NaN         NaN
# 13903         NaN      NaN         NaN         NaN         NaN         NaN
# 3052          NaN      NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 52 columns]

# %%
shoes["midprices"]=(shoes["prices.amountMax"]+shoes["prices.amountMin"])/2
probplot(shoes["midprices"],dist="norm",plot=pylab)
plt.show()
